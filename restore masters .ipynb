# %%
# importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # OR from matplotlib import pyplot as plt

# %%
# importing the dataset to Pandas DataFrame: cars_df
cars_df = pd.read_csv(r'C:\Users\suved\OneDrive\Documents\auto_mpg.csv')

# %%
# display the data in DataFrame: cars_df
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
#display first five rows of the DataFrame: cars_df
cars_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#display last five rows of the DataFrame: cars_df
cars_df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
# Check the number of rows and  number of columns in Pandas DataFrame: cars_df
cars_df.shape
# Out:
# (398, 9)

# %%
# check the row index labels of Pandas DataFrame: cars_df
cars_df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
# Check the column labels of Pandas DataFrame: cars_df
cars_df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
# Get the concise summary of DataFrame: cars_df
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
# Get the statistical summary of numeric columns of DataFrame: cars_df
cars_df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
 # finding missing values using isna() and any() in columns of the DataFrame: cars_df
cars_df.isna().sum() # cars_df.isnull()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
# finding the number of missing values in each of the columns of the DataFrame: cars_df
cars_df.isna()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model_year  origin   name
# 0         False   False  False
# 1         False   False  False
# ...

# %%
cars_df[['horsepower']].isna() # <-- this is a conditional statement which gives T/F
# Out:
#      horsepower
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 393       False
# 394       False
# 395       False
# 396       False
# 397       False
#
# [398 rows x 1 columns]

# %%
print(cars_df['cylinders'].unique().size)
print(cars_df['model_year'].unique().size)
print(cars_df['weight'].unique().size)
print(cars_df['cylinders'].unique())
print(cars_df['model_year'].unique())
# Out:
# 5
# 13
# 351
# [8 4 6 3 5]
# [70 71 72 73 74 75 76 77 78 79 80 81 82]

# %%
cars_df[['horsepower']]
# Out:
#      horsepower
# 0         130.0
# 1         165.0
# 2         150.0
# 3         150.0
# 4         140.0
# ..          ...
# 393        86.0
# 394        52.0
# 395        84.0
# 396        79.0
# 397        82.0
#
# [398 rows x 1 columns]

# %%
cars_df['horsepower'].mean()
# Out:
# 104.46938775510205

# %%
# finding the rows where missing values are present
cars_df[cars_df['horsepower'].isna()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
cars_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars_df.groupby(['cylinders', 'model_year'])[['horsepower']].count().rename(columns = {'horsepower': 'Count'})
# Out:
#                       Count
# cylinders model_year
# 3         72              1
#           73              1
#           77              1
#           80              1
# 4         70              7
#           71             12
#           72             14
#           73             11
#           74             15
#           75             12
#           76             15
#           77             14
#           78             17
#           79             12
#           80             23
#           81             20
#           82             27
# 5         78              1
#           79              1
#           80              1
# 6         70              4
#           71              8
#           73              8
#           74              6
#           75             12
#           76             10
#           77              5
#           78             12
#           79              6
#           80              2
#           81              7
# ...

# %%
def fill(x):
    return x.fillna(x.mean())

# %%
cars_df['horsepower'] = cars_df.groupby(['cylinders', 'model_year'])['horsepower'].transform(lambda x: x.fillna(x.mean()))

# %%
"""viewing all the values that we filled right now."""
cars_df.iloc[[32, 126, 330, 336, 354, 374]]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0   77.583333    2046          19.0
# 126  21.0          6         200.0  101.666667    2875          17.0
# 330  40.9          4          85.0   74.043478    1835          17.3
# 336  23.6          4         140.0   74.043478    2905          14.3
# 354  34.5          4         100.0   72.950000    2320          15.8
# 374  23.0          4         151.0   79.148148    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
# checking for missing values in columns of the DataFrame: cars_df
cars_df.isna().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
# find the number of duplicate records the DataFrame: cars_df
cars_df.duplicated().sum()
# Out:
# 0

# %%
# get the duplicate records in the DataFrame: cars_df
cars_df[cars_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %%
# dropping the duplicate records in the DataFrame: cars_df
cars_df.drop_duplicates(inplace=True)
cars_df.duplicated().sum()
# Out:
# 0

# %%
# get the data types of all columns of the DataFrame: cars_df
cars_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# setting data type of origin as 'category'
cars_df['origin']=cars_df['origin'].astype('category')
cars_df['origin'].dtype
# Out:
# CategoricalDtype(categories=['europe', 'japan', 'usa'], ordered=False)

# %%
# A boxplot gives a good indication of distribution of data about the median. 
# Boxplots are a standardized way of displaying the distribution of data based 
# on the five-number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), 
# and “maximum”).

cars_df['acceleration'].plot(kind='box')
# Out:
# <Axes: >

# %%
# box-plot for all numerical columns of the DataFrame: cars_df
# plt.subplot(norows, ncols, plot_number)
# Plotting subplots On a grid of 2 rows x 3 columns

# box plot for mpg
plt.subplot(2,3,1)
cars_df['mpg'].plot(kind='box') 

# box plot for displacement
plt.subplot(2,3,2) 
cars_df['displacement'].plot(kind='box') 

# box plot for horsepower
plt.subplot(2,3,3) 
cars_df['horsepower'].plot(kind='box') 

# box plot for weight
plt.subplot(2,3,4) 
cars_df['weight'].plot(kind='box') 

# box plot for acceleration
plt.subplot(2,3,5) 
cars_df['acceleration'].plot(kind='box') 

plt.tight_layout()
plt.show()

# %%
cars_df[['mpg','displacement','horsepower','weight','acceleration']].describe()
# Out:
#               mpg  displacement  horsepower       weight  acceleration
# count  398.000000    398.000000  398.000000   398.000000    398.000000
# mean    23.514573    193.425879  104.099083  2970.424623     15.568090
# std      7.815984    104.269838   38.336173   846.841774      2.757689
# min      9.000000     68.000000   46.000000  1613.000000      8.000000
# 25%     17.500000    104.250000   75.000000  2223.750000     13.825000
# 50%     23.000000    148.500000   92.000000  2803.500000     15.500000
# 75%     29.000000    262.000000  125.000000  3608.000000     17.175000
# max     46.600000    455.000000  230.000000  5140.000000     24.800000

# %%
# finding the upper and lower limit of horespower and acceleration columns

def find_outlier_limits(col_name):
    Q1,Q3=cars_df[col_name].quantile([.25,.75])
    IQR=Q3-Q1
    low=Q1-(1.5* IQR)
    high=Q3+(1.5* IQR)
    return (high,low)

high_hp,low_hp=find_outlier_limits('horsepower')
print('Horsepower: ','upper limit: ',high_hp,' lower limit: ',low_hp)
high_acc,low_acc=find_outlier_limits('acceleration')
print('Acceleration: ','upper limit: ',high_acc,' lower limit:',low_acc)

# Replacing outlier values in horespower and acceleration columns with respective 
# upper and lower limits

cars_df.loc[cars_df['horsepower']>high_hp,'horsepower']=high_hp
cars_df.loc[cars_df['acceleration']>high_acc,'acceleration']=high_acc
cars_df.loc[cars_df['acceleration']<low_acc,'acceleration']=low_acc
# Out:
# Horsepower:  upper limit:  200.0  lower limit:  0.0
# Acceleration:  upper limit:  22.2  lower limit: 8.8

# %%
# box-plot for all numerical columns of the DataFrame: cars_df
# plt.subplot(norows, ncols, plot_number)
# Plotting subplots On a grid of 2 rows x 3 columns

# box plot for mpg
plt.subplot(2,3,1)
cars_df['mpg'].plot(kind='box') 

# box plot for displacement
plt.subplot(2,3,2) 
cars_df['displacement'].plot(kind='box') 

# box plot for horsepower
plt.subplot(2,3,3) 
cars_df['horsepower'].plot(kind='box') 

# box plot for horsepower
plt.subplot(2,3,4) 
cars_df['weight'].plot(kind='box') 

# box plot for acceleration
plt.subplot(2,3,5) 
cars_df['acceleration'].plot(kind='box') 

plt.tight_layout()

# %%
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# finding the names of the unique car serviced
cars_df['name'].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'ford pinto', 'plymouth satellite custom', 'ford torino 500',
#        'amc matador', 'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
# ...

# %%
# finding the number of unique car serviced 
cars_df['name'].unique().size
# Out:
# 305

# %%
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# Extracting the company name from the name column
cars_df['company']=cars_df['name'].apply(lambda x: x.split()[0])
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    company
# 0            70     usa  chevrolet chevelle malibu  chevrolet
# ...

# %%
# finding the number of unique companies 
cars_df['company'].unique().size
# Out:
# 37

# %%
# get the names of the companies
cars_df['company'].unique()
# Out:
# array(['chevrolet', 'buick', 'plymouth', 'amc', 'ford', 'pontiac',
#        'dodge', 'toyota', 'datsun', 'volkswagen', 'peugeot', 'audi',
#        'saab', 'bmw', 'chevy', 'hi', 'mercury', 'opel', 'fiat',
#        'oldsmobile', 'chrysler', 'mazda', 'volvo', 'renault', 'toyouta',
#        'maxda', 'honda', 'subaru', 'chevroelt', 'capri', 'vw',
#        'mercedes-benz', 'cadillac', 'mercedes', 'vokswagen', 'triumph',
#        'nissan'], dtype=object)

# %%
cars_df.groupby('company')[['name']].count().rename(columns = {'name': 'count'})
# Out:
#                count
# company
# amc               28
# audi               7
# bmw                2
# buick             17
# cadillac           2
# capri              1
# chevroelt          1
# chevrolet         43
# chevy              3
# chrysler           6
# datsun            23
# dodge             28
# fiat               8
# ford              51
# hi                 1
# honda             13
# maxda              2
# mazda             10
# mercedes           1
# mercedes-benz      2
# mercury           11
# nissan             1
# oldsmobile        10
# opel               4
# peugeot            8
# plymouth          31
# pontiac           16
# renault            5
# saab               4
# subaru             4
# toyota            25
# toyouta            1
# triumph            1
# vokswagen          1
# volkswagen        15
# volvo              6
# vw                 6

# %%
# getting count of cars by company 
company_count_df=cars_df.groupby('company')[['name']].count().sort_values('name',ascending=False).rename(columns={'name':'cars_count'})
company_count_df
# Out:
#                cars_count
# company
# ford                   51
# chevrolet              43
# plymouth               31
# amc                    28
# dodge                  28
# toyota                 25
# datsun                 23
# buick                  17
# pontiac                16
# volkswagen             15
# honda                  13
# mercury                11
# oldsmobile             10
# mazda                  10
# fiat                    8
# peugeot                 8
# audi                    7
# volvo                   6
# vw                      6
# chrysler                6
# renault                 5
# saab                    4
# opel                    4
# subaru                  4
# chevy                   3
# maxda                   2
# bmw                     2
# cadillac                2
# mercedes-benz           2
# chevroelt               1
# capri                   1
# toyouta                 1
# triumph                 1
# vokswagen               1
# ...

# %%
# visualize company and car count (bar graph). A bar chart is a graph with rectangular bars 
# that usually compare different categories. Each bar represents a particular category. 
# The length of the bar indicates the total number of values or items in that category.

company_count_df.plot(kind='bar',width=0.3)
# Out:
# <Axes: xlabel='company'>

# %%
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    company
# 0            70     usa  chevrolet chevelle malibu  chevrolet
# ...

# %%
# getting the unique origins of the cars serviced
cars_df['origin'].unique()
# Out:
# ['usa', 'japan', 'europe']
# Categories (3, object): ['europe', 'japan', 'usa']

# %%
# getting count of cars by origin 
origin_count_df=cars_df.groupby('origin')[['name']].count().sort_values('name',ascending=False).rename(columns={'name':'cars_count'})
origin_count_df
# Out:
#         cars_count
# origin
# usa            249
# japan           79
# europe          70

# %%
# visualize origin and car count (bar graph)
origin_count_df.plot(kind='bar',width=0.3)
# Out:
# <Axes: xlabel='origin'>

# %%
# getting the percentage of cars serviced from USA

originwise_percent=((origin_count_df.loc['usa','cars_count']/cars_df.shape[0])*100)
originwise_percent
# Out:
# 62.562814070351756

# %%
Region_origin = cars_df.origin.value_counts().index
print(Region_origin)
Origin_value = cars_df.origin.value_counts().values
print(Origin_value)
plt.figure(figsize=(6,6))
plt.pie(Origin_value,colors = ["red","aqua","green"],autopct = "%1.2f%%",pctdistance=0.8,wedgeprops={'width': 0.4})
plt.legend(Region_origin,loc='upper right')
plt.show()
# Out:
# CategoricalIndex(['usa', 'japan', 'europe'], categories=['europe', 'japan', 'usa'], ordered=False, dtype='category', name='origin')
# [249  79  70]

# %%
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    company
# 0            70     usa  chevrolet chevelle malibu  chevrolet
# ...

# %%
# getting the unique models of the cars serviced
cars_df['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
# getting count of cars by model year
model_count_df=cars_df.groupby('model_year')[['name']].count().rename(columns={'name':'cars_count'})
model_count_df
# Out:
#             cars_count
# model_year
# 70                  29
# 71                  28
# 72                  28
# 73                  40
# 74                  27
# 75                  30
# 76                  34
# 77                  28
# 78                  36
# 79                  29
# 80                  29
# 81                  29
# 82                  31

# %%
# visualize Model Year and car count (bar graph)
model_count_df.plot(kind='line')
# Out:
# <Axes: xlabel='model_year'>

# %%
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    company
# 0            70     usa  chevrolet chevelle malibu  chevrolet
# ...

# %%
# getting the unique cylinders of the cars serviced
cars_df['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
# getting count of cars by cylinders
cylinder_count_df=cars_df.groupby('cylinders')[['name']].count().rename(columns={'name':'cars_count'})
cylinder_count_df
# Out:
#            cars_count
# cylinders
# 3                   4
# 4                 204
# 5                   3
# 6                  84
# 8                 103

# %%
# getting the percentage of cars serviced with 4 cylinders

cylinderwise_percent=((cylinder_count_df.loc[4][0]/cars_df.shape[0])*100)
cylinderwise_percent
# Out:
# 51.256281407035175

# %%
# filtering cars with 3 or 5 cylinders
cars_df[(cars_df['cylinders']==3) | (cars_df['cylinders']==5)][['origin','model_year','name','company','cylinders']]
# Out:
#      origin  model_year                 name   company  cylinders
# 71    japan          72      mazda rx2 coupe     mazda          3
# 111   japan          73            maxda rx3     maxda          3
# 243   japan          77           mazda rx-4     mazda          3
# 274  europe          78            audi 5000      audi          5
# 297  europe          79   mercedes benz 300d  mercedes          5
# 327  europe          80  audi 5000s (diesel)      audi          5
# 334   japan          80        mazda rx-7 gs     mazda          3

# %%
# A scatter plot helps to observe the relationship between variables.
# Scatter plot between cylinders and mpg columns of the DataFrame: cars_df
cars_df.plot(x='cylinders',y='mpg', kind='scatter')
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
cars_df.groupby(['model_year','cylinders'])[['name', 'company']].count()
# Out:
#                       name  company
# model_year cylinders
# 70         4             7        7
#            6             4        4
#            8            18       18
# 71         4            13       13
#            6             8        8
#            8             7        7
# 72         3             1        1
#            4            14       14
#            8            13       13
# 73         3             1        1
#            4            11       11
#            6             8        8
#            8            20       20
# 74         4            15       15
#            6             7        7
#            8             5        5
# 75         4            12       12
#            6            12       12
#            8             6        6
# 76         4            15       15
#            6            10       10
#            8             9        9
# 77         3             1        1
#            4            14       14
# ...

# %%
# Trends by Model Year and cylinders
model_cylinder_df=cars_df.groupby(['model_year','cylinders'])[['name']].count().rename(columns={'name':'cars_count'})
model_cylinder_df
# Out:
#                       cars_count
# model_year cylinders
# 70         4                   7
#            6                   4
#            8                  18
# 71         4                  13
#            6                   8
#            8                   7
# 72         3                   1
#            4                  14
#            8                  13
# 73         3                   1
#            4                  11
#            6                   8
#            8                  20
# 74         4                  15
#            6                   7
#            8                   5
# 75         4                  12
#            6                  12
#            8                   6
# 76         4                  15
#            6                  10
#            8                   9
# 77         3                   1
#            4                  14
#            6                   5
#            8                   8
# ...

# %%
model_cylinder_df.reset_index(inplace=True)

# %%
model_cylinder_df.head(10)
# Out:
#    model_year  cylinders  cars_count
# 0          70          4           7
# 1          70          6           4
# 2          70          8          18
# 3          71          4          13
# 4          71          6           8
# 5          71          8           7
# 6          72          3           1
# 7          72          4          14
# 8          72          8          13
# 9          73          3           1

# %%
model_pivot=pd.pivot_table(model_cylinder_df[['model_year','cylinders','cars_count']], index='model_year', columns='cylinders', values='cars_count', aggfunc=np.sum)
model_pivot
# Out:
# cylinders     3     4    5     6     8
# model_year
# 70          NaN   7.0  NaN   4.0  18.0
# 71          NaN  13.0  NaN   8.0   7.0
# 72          1.0  14.0  NaN   NaN  13.0
# 73          1.0  11.0  NaN   8.0  20.0
# 74          NaN  15.0  NaN   7.0   5.0
# 75          NaN  12.0  NaN  12.0   6.0
# 76          NaN  15.0  NaN  10.0   9.0
# 77          1.0  14.0  NaN   5.0   8.0
# 78          NaN  17.0  1.0  12.0   6.0
# 79          NaN  12.0  1.0   6.0  10.0
# 80          1.0  25.0  1.0   2.0   NaN
# 81          NaN  21.0  NaN   7.0   1.0
# 82          NaN  28.0  NaN   3.0   NaN

# %%
model_pivot.plot(kind='bar', stacked='True',figsize=(7,5))
# Out:
# <Axes: xlabel='model_year'>

# %%
# Trends by origin and cylinders
origin_cylinder_df=cars_df.groupby(['origin','cylinders'])[['name']].count().rename(columns={'name':'cars_count'})
origin_cylinder_df.reset_index(inplace=True)
origin_pivot=pd.pivot_table(origin_cylinder_df[['origin','cylinders','cars_count']], index='origin', columns='cylinders', values='cars_count', aggfunc=np.sum)
origin_pivot.plot(kind='bar', stacked='True',figsize=(7,5))
# Out:
# <Axes: xlabel='origin'>

# %%
# Trends by Model year and origin

model_origin_df=cars_df.groupby(['model_year','origin'])[['name']].count().rename(columns={'name':'cars_count'})
model_origin_df.reset_index(inplace=True)
modorg_pivot=pd.pivot_table(model_origin_df[['model_year','origin','cars_count']], index='model_year', columns='origin', values='cars_count', aggfunc=np.sum)
modorg_pivot.plot(kind='bar', stacked='True',figsize=(7,5))
# Out:
# <Axes: xlabel='model_year'>

# %%
model_origin_df=cars_df.groupby(['model_year','origin'])[['name']].count().reset_index().rename(columns={'name':'cars_count'})
# visualize origin wise - year and car_count (line)
#creating an empty canvas/figure
fig = plt.figure(figsize=[5,5]) #figsize represents width and height in inches. Default value is [6.4, 4.8]
#Adding single axes to the figure 
ax1 = fig.add_axes([0, 0, 1, 1]) #The dimensions [left, bottom, width, height] of the new Axes with respect to figure size
model_origin_df[model_origin_df['origin']=='usa'].plot( ax=ax1, x = "model_year", y = "cars_count",kind = "line",color='green', linewidth=4, label='USA' )
model_origin_df[model_origin_df['origin']=='japan'].plot(ax=ax1, x = "model_year", y = "cars_count",kind = "line",color='blue', linewidth=4, label='Japan' )
model_origin_df[model_origin_df['origin']=='europe'].plot(ax=ax1, x = "model_year", y = "cars_count",kind = "line",color='red', linewidth=4, label='Europe' )
plt.legend()

# %%
# visualize yearwise - origin and car_count (pie)
# visual representation of empty sub plots
fig,ax=plt.subplots(3,5,figsize=(20,15))
ax[0][0].set_title('model year - 70')
model_origin_df[model_origin_df['model_year']==70].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==70]['origin'], y='cars_count',ax=ax[0][0],autopct='%.2f%%')
ax[0][1].set_title('model year - 71')
model_origin_df[model_origin_df['model_year']==71].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==71]['origin'], y='cars_count',ax=ax[0][1],autopct='%.2f%%')
ax[0][2].set_title('model year - 72')
model_origin_df[model_origin_df['model_year']==72].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==72]['origin'], y='cars_count',ax=ax[0][2],autopct='%.2f%%')
ax[0][3].set_title('model year - 73')
model_origin_df[model_origin_df['model_year']==73].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==73]['origin'], y='cars_count',ax=ax[0][3],autopct='%.2f%%')
ax[0][4].set_title('model year - 74')
model_origin_df[model_origin_df['model_year']==74].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==74]['origin'], y='cars_count',ax=ax[0][4],autopct='%.2f%%')
ax[1][0].set_title('model year - 75')
model_origin_df[model_origin_df['model_year']==75].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==75]['origin'], y='cars_count',ax=ax[1][0],autopct='%.2f%%')
ax[1][1].set_title('model year - 76')
model_origin_df[model_origin_df['model_year']==76].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==76]['origin'], y='cars_count',ax=ax[1][1],autopct='%.2f%%')
ax[1][2].set_title('model year - 77')
model_origin_df[model_origin_df['model_year']==77].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==77]['origin'], y='cars_count',ax=ax[1][2],autopct='%.2f%%')
ax[1][3].set_title('model year - 78')
model_origin_df[model_origin_df['model_year']==78].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==78]['origin'], y='cars_count',ax=ax[1][3],autopct='%.2f%%')
ax[1][4].set_title('model year - 79')
model_origin_df[model_origin_df['model_year']==79].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==79]['origin'], y='cars_count',ax=ax[1][4],autopct='%.2f%%')
ax[2][1].set_title('model year - 80')
model_origin_df[model_origin_df['model_year']==80].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==80]['origin'], y='cars_count',ax=ax[2][1],autopct='%.2f%%')
ax[2][2].set_title('model year - 81')
model_origin_df[model_origin_df['model_year']==81].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==81]['origin'], y='cars_count',ax=ax[2][2],autopct='%.2f%%')
ax[2][3].set_title('model year - 82')
model_origin_df[model_origin_df['model_year']==82].plot(kind='pie',labels=model_origin_df[model_origin_df['model_year']==82]['origin'], y='cars_count',ax=ax[2][3],autopct='%.2f%%')
plt.tight_layout()

# %%
# origin, year, mean mpg - line graph
mpg_df=cars_df.groupby(['origin','model_year'])[['mpg']].mean().reset_index()
fig = plt.figure(figsize=[5,5])
ax = fig.add_axes([0, 0, 1, 1])
mpg_df[mpg_df['origin']=='usa'].plot( ax=ax, x = "model_year", y = "mpg",kind = "line",color='green', linewidth=4, label='USA' )
mpg_df[mpg_df['origin']=='japan'].plot(ax=ax, x = "model_year", y = "mpg",kind = "line",color='blue', linewidth=4, label='Japan' )
mpg_df[mpg_df['origin']=='europe'].plot(ax=ax, x = "model_year", y = "mpg",kind = "line",color='red', linewidth=4, label='Europe' )
plt.legend()

# %%
# for every origin, min max and mean mpg across model years
cars_df['origin']=cars_df['origin'].astype('object')
mpg_pivot=pd.pivot_table(cars_df, values ='mpg', index ='model_year', columns ='origin', aggfunc = [np.mean, np.max, np.min])
mpg_pivot
# Out:
#                  mean                         amax               amin        \
# origin         europe      japan        usa europe japan   usa europe japan
# model_year
# 70          25.200000  25.500000  15.272727   26.0  27.0  22.0   24.0  24.0
# 71          28.750000  29.500000  18.100000   30.0  35.0  28.0   27.0  25.0
# 72          22.000000  24.200000  16.277778   26.0  28.0  28.0   18.0  19.0
# 73          24.000000  20.000000  15.034483   29.0  22.0  23.0   19.0  18.0
# 74          27.000000  29.333333  18.333333   31.0  32.0  28.0   24.0  24.0
# 75          24.500000  27.500000  17.550000   29.0  33.0  23.0   22.0  24.0
# 76          24.250000  28.000000  19.431818   29.5  33.0  29.0   16.5  19.0
# 77          29.250000  27.416667  20.722222   36.0  33.5  33.5   21.5  21.5
# 78          24.950000  29.687500  21.772727   43.1  39.4  36.1   16.2  21.1
# 79          30.450000  32.950000  23.478261   37.3  34.1  35.7   25.4  31.8
# ...

# %%
mpg_pivot.reset_index(inplace=True)
mpg_pivot
# Out:
#        model_year       mean                         amax               amin  \
# origin                europe      japan        usa europe japan   usa europe
# 0              70  25.200000  25.500000  15.272727   26.0  27.0  22.0   24.0
# 1              71  28.750000  29.500000  18.100000   30.0  35.0  28.0   27.0
# 2              72  22.000000  24.200000  16.277778   26.0  28.0  28.0   18.0
# 3              73  24.000000  20.000000  15.034483   29.0  22.0  23.0   19.0
# 4              74  27.000000  29.333333  18.333333   31.0  32.0  28.0   24.0
# 5              75  24.500000  27.500000  17.550000   29.0  33.0  23.0   22.0
# 6              76  24.250000  28.000000  19.431818   29.5  33.0  29.0   16.5
# 7              77  29.250000  27.416667  20.722222   36.0  33.5  33.5   21.5
# 8              78  24.950000  29.687500  21.772727   43.1  39.4  36.1   16.2
# 9              79  30.450000  32.950000  23.478261   37.3  34.1  35.7   25.4
# ...

# %%
plt.figure(figsize=(12,5))
ax1=plt.subplot(1,3,1)
plt.title('USA')
plt.plot(mpg_pivot['model_year'], mpg_pivot['mean']['usa'],color='green', linewidth=1, label='mean' )
plt.plot(mpg_pivot['model_year'], mpg_pivot['amax']['usa'],color='blue', linewidth=1, label='max' )
plt.plot(mpg_pivot['model_year'], mpg_pivot['amin']['usa'],color='red', linewidth=1, label='min' )
plt.legend()
plt.subplot(1,3,2, sharey=ax1)
plt.title('Japan')
plt.plot(mpg_pivot['model_year'], mpg_pivot['mean']['japan'],color='green', linewidth=1, label='mean' )
plt.plot(mpg_pivot['model_year'], mpg_pivot['amax']['japan'],color='blue', linewidth=1, label='max' )
plt.plot(mpg_pivot['model_year'], mpg_pivot['amin']['japan'],color='red', linewidth=1, label='min' )
plt.legend()
plt.subplot(1,3,3, sharey=ax1)
plt.title('Europe')
plt.plot(mpg_pivot['model_year'], mpg_pivot['mean']['europe'],color='green', linewidth=1, label='mean' )
plt.plot(mpg_pivot['model_year'], mpg_pivot['amax']['europe'],color='blue', linewidth=1, label='max' )
plt.plot(mpg_pivot['model_year'], mpg_pivot['amin']['europe'],color='red', linewidth=1, label='min' )
plt.legend()
plt.tight_layout()

# %%
# origin, year, mean horsepower - line graph
mpg_df=cars_df.groupby(['origin','model_year'])[['horsepower']].mean().reset_index()
fig = plt.figure(figsize=[5,5])
ax = fig.add_axes([0, 0, 1, 1])
mpg_df[mpg_df['origin']=='usa'].plot( ax=ax, x = "model_year", y = "horsepower",kind = "line",color='green', linewidth=4, label='USA' )
mpg_df[mpg_df['origin']=='japan'].plot(ax=ax, x = "model_year", y = "horsepower",kind = "line",color='blue', linewidth=4, label='Japan' )
mpg_df[mpg_df['origin']=='europe'].plot(ax=ax, x = "model_year", y = "horsepower",kind = "line",color='red', linewidth=4, label='Europe' )
plt.legend()

# %%
# correlation
correlation_df=cars_df[['mpg','cylinders','displacement','horsepower','weight','acceleration']].corr()
correlation_df
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.787786 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.855492  0.896017
# displacement -0.804203   0.950721      1.000000    0.901515  0.932824
# horsepower   -0.787786   0.855492      0.901515    1.000000  0.874652
# weight       -0.831741   0.896017      0.932824    0.874652  1.000000
# acceleration  0.418293  -0.509344     -0.548667   -0.693798 -0.422492
#
#               acceleration
# mpg               0.418293
# cylinders        -0.509344
# displacement     -0.548667
# horsepower       -0.693798
# weight           -0.422492
# acceleration      1.000000

# %%
# correlation between numerical columns
import seaborn as sns
sns.heatmap(correlation_df, cmap="coolwarm", annot = True)
# Out:
# <Axes: >

# %%
cars_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name    company
# 0          70    usa  chevrolet chevelle malibu  chevrolet
# 1          70    usa          buick skylark 320      buick
# 2          70    usa         plymouth satellite   plymouth
# 3          70    usa              amc rebel sst        amc
# 4          70    usa                ford torino       ford

# %%
# based on mpg and cylinders, creating a new column - car_type (hatchback, sedan, SUV, sports)

cars_df.loc[(cars_df['cylinders']==3),'car_type']='Hatchback'
cars_df.loc[(cars_df['cylinders']==4) & (cars_df['mpg']>=30),'car_type']='Hatchback'
cars_df.loc[(cars_df['cylinders']==5),'car_type']='Sedan'
cars_df.loc[(cars_df['cylinders']==4) & (cars_df['mpg']<30),'car_type']='Sedan'
cars_df.loc[(cars_df['cylinders']==6),'car_type']='SUV'
cars_df.loc[(cars_df['cylinders']==8),'car_type']='Sports'
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    company   car_type
# ...

# %%
# number of cars under each type
cars_df.groupby('car_type')[['name']].count()
# Out:
#            name
# car_type
# Hatchback    92
# SUV          84
# Sedan       119
# Sports      103

# %%
# mean metrics of different car types
metrics_df=cars_df.groupby('car_type')[['mpg','displacement','horsepower','weight','acceleration']].mean().sort_values('mpg',ascending=False)
metrics_df
# Out:
#                  mpg  displacement  horsepower       weight  acceleration
# car_type
# Hatchback  34.028261     97.097826   71.184712  2128.521739     16.476087
# Sedan      25.278992    119.247899   84.460294  2470.067227     16.571429
# SUV        19.985714    218.142857  101.507937  3198.226190     16.263095
# Sports     14.963107    345.009709  156.475728  4114.718447     12.968932

# %%
# multiple line graph
metrics_df[['mpg','displacement','horsepower','acceleration']].plot()
# Out:
# <Axes: xlabel='car_type'>

# %%
# number of cars under differnt origin and differnt car_type
pd.crosstab(cars_df['origin'],cars_df['car_type'])
# Out:
# car_type  Hatchback  SUV  Sedan  Sports
# origin
# europe           20    4     46       0
# japan            50    6     23       0
# usa              22   74     50     103

# %%
weights_df=cars_df[cars_df['car_type'] != 'Sports'][['name','weight']]
weights_df['new_weight']=weights_df['weight'] + 5
weights_df
# Out:
#                       name  weight  new_weight
# 14   toyota corona mark ii    2372        2377
# 15         plymouth duster    2833        2838
# 16              amc hornet    2774        2779
# 17           ford maverick    2587        2592
# 18            datsun pl510    2130        2135
# ..                     ...     ...         ...
# 393        ford mustang gl    2790        2795
# 394              vw pickup    2130        2135
# 395          dodge rampage    2295        2300
# 396            ford ranger    2625        2630
# 397             chevy s-10    2720        2725
#
# [295 rows x 3 columns]

# %%
# The previously imported DataFrame: cars_df will be used for model building
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    company   car_type
# ...

# %%
#Creating matrix of predictors
X = cars_df.iloc[:, 1:8]
#Setting target
y = cars_df.iloc[:, 0]
print(X)
print(y)
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          22.2          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0       usa
# 1       usa
# 2       usa
# 3       usa
# ...

# %%
X = pd.get_dummies(X)
X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          22.2          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin_europe  origin_japan  origin_usa
# ...

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (318, 9)
# (80, 9)
# (318,)
# (80,)

# %%
#Applying standard scaler on the data
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale.fit_transform(X_train)
scale.transform(X_test)
# Out:
# array([[ 1.49526939e+00,  1.55114495e+00,  1.38939584e+00,
#          1.38121932e+00, -9.99664748e-01, -1.13752513e+00,
#         -4.72310198e-01, -5.06869802e-01,  7.94209815e-01],
#        [-8.52857354e-01, -5.04710772e-01, -7.72268904e-01,
#         -4.99341807e-01,  5.22084366e-01, -5.89029314e-01,
#         -4.72310198e-01, -5.06869802e-01,  7.94209815e-01],
#        [ 1.49526939e+00,  1.07371874e+00,  1.02911839e+00,
#          1.57674079e+00,  1.41647087e-01, -1.13752513e+00,
#         -4.72310198e-01, -5.06869802e-01,  7.94209815e-01],
#        [-8.52857354e-01, -6.99578613e-01, -4.39705097e-01,
#          1.84938650e-02,  1.47317756e+00, -1.13752513e+00,
#          2.11725261e+00, -5.06869802e-01, -1.25911312e+00],
#        [ 3.21206016e-01,  3.91681296e-01, -7.94276387e-02,
#          3.84652269e-01, -4.85715519e-02, -1.41177304e+00,
#         -4.72310198e-01, -5.06869802e-01,  7.94209815e-01],
#        [-8.52857354e-01, -1.16726143e+00, -9.38550807e-01,
# ...

# %%
#Importing the algorithm
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
#Fitting the model on training data
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Checking the coefficient(slope) and intercepts
m = reg.coef_
c = reg.intercept_
m,c
# Out:
# (array([-0.36669643,  0.02475106, -0.03475517, -0.00627841,  0.11103444,
#          0.75647496,  0.72383159,  1.2373965 , -1.9612281 ]),
#  -15.51378498640063)

# %%
#Predicting the target: mpg against the predictors in the training data set
#Predicted data stored in y_pred_train
y_pred_train = reg.predict(X_train)

# %%
#Predicting the target: mpg against the predictors in the testing data set
#Predicted data stored in y_pred_test
y_pred_test = reg.predict(X_test)

# %%
# Prediction Accuracy in terms of how close is the predicted value of target: mpg
# to the real value in training data set
from sklearn.metrics import r2_score
r2_S = r2_score(y_train, y_pred_train)
r2_S
# Out:
# 0.8215539673604749

# %%
# Prediction Accuracy in terms of how close the predicted value of target: mpg
# to the real value in testing data set
from sklearn.metrics import r2_score
r2_S = r2_score(y_test, y_pred_test)
r2_S
# Out:
# 0.8294001619272308

# %%
# new instance of car to be serviced
car={'cylinders':[4], 'displacement':[110], 'horsepower':[70], 'weight':[2500], 'acceleration':[16.5],'model_year':[76], 'origin_europe':[0], 'origin_japan':[1], 'origin_usa':[0]}
print(reg.predict(pd.DataFrame(car)))
# Out:
# [28.17472294]

# %%
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name    company   car_type
# ...

# %%
#Creating matrix of predictors
X = cars_df.iloc[:, 0:8]
#Setting target
y = cars_df.iloc[:, 10]
print(X)
print(y)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70     usa
# 1            70     usa
# 2            70     usa
# 3            70     usa
# ...

# %%
X = pd.get_dummies(X)
X
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          22.2
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin_europe  origin_japan  origin_usa
# 0            70          False         False        True
# ...

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Applying standard scaler on the data
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale.fit_transform(X_train)
scale.transform(X_test);

# %%
#Importing the algorithm
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5,metric="euclidean")

# %%
#Fitting the model on training data
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
#Predicting the target: mpg against the predictors in the training data set
#Predicted data stored in y_pred_train
y_pred_train = classifier.predict(X_train)

# %%
#Predicting the target: mpg against the predictors in the testing data set
#Predicted data stored in y_pred_test
y_pred_test = classifier.predict(X_test)

# %%
#Training accuracy
from sklearn.metrics import accuracy_score
train_accuracy_score = accuracy_score(y_train, y_pred_train)
train_accuracy_score
# Out:
# 0.8616352201257862

# %%
#Testing accuracy
from sklearn.metrics import accuracy_score
test_accuracy_score = accuracy_score(y_test, y_pred_test)
test_accuracy_score
# Out:
# 0.8125

# %%
# new instance of car to be serviced
car={'mpg':[10],'cylinders':[8], 'displacement':[200], 'horsepower':[100], 'weight':[2500], 'acceleration':[16.5],'model_year':[76], 'origin_europe':[0], 'origin_japan':[0], 'origin_usa':[1]}
print(classifier.predict(pd.DataFrame(car)))
# Out:
# ['Sedan']
